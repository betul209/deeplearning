# %% [markdown]
# I could not manage to download a zip file, unzip and load it here by code. I kept getting the same error. which is connection error to the github page although I tried many solutions from the internet. Therefore, it uses local files in the following link: https://github.com/betul209/deeplearning/blob/e0522abd50a60b21c57b44967640c706055b4c51/dat.zip

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %% [markdown]
# To ease reading and running the code, I decided to put directories here:

# %%
DATA_DIR = r"/mnt/c/Users/psybe/Desktop/dat"
FINALDATA_DIR = r"/mnt/c/Users/psybe/Desktop/dat_split"

# %% [markdown]
# I did not use the data for my project so I found another dataset from internet and used it. Each image in the dataset contains two images, each of them either labeled as real or impossible depending on if the image is possible to exist in 3D space. Images are simple drawing illusions, and their labels are in their file names. I only included 800 images from Illusion Visual Question dataset (impossible object class) however it is part of the following project: https://illusionvqa.github.io/
#
# Since each picture includes 2 objects, I first divided images in halves and saved them as individual images, with their labels.

# %%
def split_and_save_images(input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)

    for file_name in os.listdir(input_dir):
        if file_name.endswith((".png", ".jpg", ".jpeg")):
            img_path = os.path.join(input_dir, file_name)

            try:
                img = Image.open(img_path)

                width, height = img.size
                mid_width = width // 2 

                left_image = img.crop((0, 0, mid_width, height)) 
                right_image = img.crop((mid_width, 0, width, height))

                base_name, ext = os.path.splitext(file_name)
                parts = base_name.split("_")
                if len(parts) < 3:
                    raise ValueError(f"No file: {file_name}")

                left_label = parts[1] 
                right_label = parts[2] 

                left_image_name = f"{parts[0]}_left_{left_label}{ext}"
                right_image_name = f"{parts[0]}_right_{right_label}{ext}"

                left_image.save(os.path.join(output_dir, left_image_name))
                right_image.save(os.path.join(output_dir, right_image_name))

                print(f"Cut in half and saved: {file_name} -> {left_image_name}, {right_image_name}")

            except Exception as e:
                print(f"Error {file_name}: {e}")

input_dir = DATA_DIR 
output_dir = FINALDATA_DIR

split_and_save_images(input_dir, output_dir)
# Out:
# Cut in half and saved: 0000_real_impossible_p.png -> 0000_left_real.png, 0000_right_impossible.png
# Cut in half and saved: 0001_impossible_real_p.png -> 0001_left_impossible.png, 0001_right_real.png
# Cut in half and saved: 0002_real_impossible_p.png -> 0002_left_real.png, 0002_right_impossible.png
# Cut in half and saved: 0003_impossible_real_p.png -> 0003_left_impossible.png, 0003_right_real.png
# Cut in half and saved: 0004_real_impossible_p.png -> 0004_left_real.png, 0004_right_impossible.png
# Cut in half and saved: 0005_impossible_real_p.png -> 0005_left_impossible.png, 0005_right_real.png
# Cut in half and saved: 0006_real_impossible_p.png -> 0006_left_real.png, 0006_right_impossible.png
# Cut in half and saved: 0007_impossible_real_p.png -> 0007_left_impossible.png, 0007_right_real.png
# Cut in half and saved: 0008_real_impossible_p.png -> 0008_left_real.png, 0008_right_impossible.png
# Cut in half and saved: 0009_impossible_real_p.png -> 0009_left_impossible.png, 0009_right_real.png
# Cut in half and saved: 0010_real_impossible_p.png -> 0010_left_real.png, 0010_right_impossible.png
# Cut in half and saved: 0011_impossible_real_p.png -> 0011_left_impossible.png, 0011_right_real.png
# Cut in half and saved: 0012_real_impossible_p.png -> 0012_left_real.png, 0012_right_impossible.png
# Cut in half and saved: 0013_impossible_real_p.png -> 0013_left_impossible.png, 0013_right_real.png
# Cut in half and saved: 0014_real_impossible_p.png -> 0014_left_real.png, 0014_right_impossible.png
# Cut in half and saved: 0015_impossible_real_p.png -> 0015_left_impossible.png, 0015_right_real.png
# Cut in half and saved: 0016_real_impossible_p.png -> 0016_left_real.png, 0016_right_impossible.png
# Cut in half and saved: 0017_impossible_real_p.png -> 0017_left_impossible.png, 0017_right_real.png
# Cut in half and saved: 0018_real_impossible_p.png -> 0018_left_real.png, 0018_right_impossible.png
# Cut in half and saved: 0019_impossible_real_p.png -> 0019_left_impossible.png, 0019_right_real.png
# Cut in half and saved: 0020_real_impossible_p.png -> 0020_left_real.png, 0020_right_impossible.png
# Cut in half and saved: 0021_impossible_real_p.png -> 0021_left_impossible.png, 0021_right_real.png
# Cut in half and saved: 0022_real_impossible_p.png -> 0022_left_real.png, 0022_right_impossible.png
# Cut in half and saved: 0023_impossible_real_p.png -> 0023_left_impossible.png, 0023_right_real.png
# Cut in half and saved: 0024_real_impossible_p.png -> 0024_left_real.png, 0024_right_impossible.png
# Cut in half and saved: 0025_impossible_real_p.png -> 0025_left_impossible.png, 0025_right_real.png
# Cut in half and saved: 0026_real_impossible_p.png -> 0026_left_real.png, 0026_right_impossible.png
# Cut in half and saved: 0027_impossible_real_p.png -> 0027_left_impossible.png, 0027_right_real.png
# Cut in half and saved: 0028_real_impossible_p.png -> 0028_left_real.png, 0028_right_impossible.png
# Cut in half and saved: 0029_impossible_real_p.png -> 0029_left_impossible.png, 0029_right_real.png
# Cut in half and saved: 0030_real_impossible_p.png -> 0030_left_real.png, 0030_right_impossible.png
# Cut in half and saved: 0031_impossible_real_p.png -> 0031_left_impossible.png, 0031_right_real.png
# Cut in half and saved: 0032_real_impossible_p.png -> 0032_left_real.png, 0032_right_impossible.png
# Cut in half and saved: 0033_impossible_real_p.png -> 0033_left_impossible.png, 0033_right_real.png
# Cut in half and saved: 0034_real_impossible_p.png -> 0034_left_real.png, 0034_right_impossible.png
# Cut in half and saved: 0035_impossible_real_p.png -> 0035_left_impossible.png, 0035_right_real.png
# Cut in half and saved: 0036_real_impossible_p.png -> 0036_left_real.png, 0036_right_impossible.png
# Cut in half and saved: 0037_impossible_real_p.png -> 0037_left_impossible.png, 0037_right_real.png
# Cut in half and saved: 0038_real_impossible_p.png -> 0038_left_real.png, 0038_right_impossible.png
# Cut in half and saved: 0039_impossible_real_p.png -> 0039_left_impossible.png, 0039_right_real.png
# Cut in half and saved: 0040_real_impossible_p.png -> 0040_left_real.png, 0040_right_impossible.png
# Cut in half and saved: 0041_impossible_real_p.png -> 0041_left_impossible.png, 0041_right_real.png
# Cut in half and saved: 0042_real_impossible_p.png -> 0042_left_real.png, 0042_right_impossible.png
# Cut in half and saved: 0043_impossible_real_p.png -> 0043_left_impossible.png, 0043_right_real.png
# Cut in half and saved: 0044_real_impossible_p.png -> 0044_left_real.png, 0044_right_impossible.png
# Cut in half and saved: 0045_impossible_real_p.png -> 0045_left_impossible.png, 0045_right_real.png
# Cut in half and saved: 0046_real_impossible_p.png -> 0046_left_real.png, 0046_right_impossible.png
# Cut in half and saved: 0047_impossible_real_p.png -> 0047_left_impossible.png, 0047_right_real.png
# Cut in half and saved: 0048_real_impossible_p.png -> 0048_left_real.png, 0048_right_impossible.png
# Cut in half and saved: 0049_impossible_real_p.png -> 0049_left_impossible.png, 0049_right_real.png
# Cut in half and saved: 0050_real_impossible_p.png -> 0050_left_real.png, 0050_right_impossible.png
# Cut in half and saved: 0051_impossible_real_p.png -> 0051_left_impossible.png, 0051_right_real.png
# Cut in half and saved: 0052_real_impossible_p.png -> 0052_left_real.png, 0052_right_impossible.png
# Cut in half and saved: 0053_impossible_real_p.png -> 0053_left_impossible.png, 0053_right_real.png
# Cut in half and saved: 0054_real_impossible_p.png -> 0054_left_real.png, 0054_right_impossible.png
# Cut in half and saved: 0055_impossible_real_p.png -> 0055_left_impossible.png, 0055_right_real.png
# Cut in half and saved: 0056_real_impossible.png -> 0056_left_real.png, 0056_right_impossible.png
# Cut in half and saved: 0057_impossible_real.png -> 0057_left_impossible.png, 0057_right_real.png
# Cut in half and saved: 0058_real_impossible.png -> 0058_left_real.png, 0058_right_impossible.png
# Cut in half and saved: 0059_impossible_real.png -> 0059_left_impossible.png, 0059_right_real.png
# Cut in half and saved: 0060_real_impossible.png -> 0060_left_real.png, 0060_right_impossible.png
# Cut in half and saved: 0061_impossible_real.png -> 0061_left_impossible.png, 0061_right_real.png
# Cut in half and saved: 0062_real_impossible.png -> 0062_left_real.png, 0062_right_impossible.png
# Cut in half and saved: 0063_impossible_real.png -> 0063_left_impossible.png, 0063_right_real.png
# Cut in half and saved: 0064_real_impossible.png -> 0064_left_real.png, 0064_right_impossible.png
# Cut in half and saved: 0065_impossible_real.png -> 0065_left_impossible.png, 0065_right_real.png
# Cut in half and saved: 0066_real_impossible.png -> 0066_left_real.png, 0066_right_impossible.png
# Cut in half and saved: 0067_impossible_real.png -> 0067_left_impossible.png, 0067_right_real.png
# Cut in half and saved: 0068_real_impossible.png -> 0068_left_real.png, 0068_right_impossible.png
# Cut in half and saved: 0069_impossible_real.png -> 0069_left_impossible.png, 0069_right_real.png
# Cut in half and saved: 0070_real_impossible.png -> 0070_left_real.png, 0070_right_impossible.png
# Cut in half and saved: 0071_impossible_real.png -> 0071_left_impossible.png, 0071_right_real.png
# Cut in half and saved: 0072_real_impossible.png -> 0072_left_real.png, 0072_right_impossible.png
# Cut in half and saved: 0073_impossible_real.png -> 0073_left_impossible.png, 0073_right_real.png
# Cut in half and saved: 0074_real_impossible.png -> 0074_left_real.png, 0074_right_impossible.png
# Cut in half and saved: 0075_impossible_real.png -> 0075_left_impossible.png, 0075_right_real.png
# Cut in half and saved: 0076_real_impossible.png -> 0076_left_real.png, 0076_right_impossible.png
# Cut in half and saved: 0077_impossible_real.png -> 0077_left_impossible.png, 0077_right_real.png
# Cut in half and saved: 0078_real_impossible.png -> 0078_left_real.png, 0078_right_impossible.png
# Cut in half and saved: 0079_impossible_real.png -> 0079_left_impossible.png, 0079_right_real.png
# Cut in half and saved: 0080_real_impossible.png -> 0080_left_real.png, 0080_right_impossible.png
# Cut in half and saved: 0081_impossible_real.png -> 0081_left_impossible.png, 0081_right_real.png
# Cut in half and saved: 0082_real_impossible.png -> 0082_left_real.png, 0082_right_impossible.png
# Cut in half and saved: 0083_impossible_real.png -> 0083_left_impossible.png, 0083_right_real.png
# Cut in half and saved: 0084_real_impossible.png -> 0084_left_real.png, 0084_right_impossible.png
# Cut in half and saved: 0085_impossible_real.png -> 0085_left_impossible.png, 0085_right_real.png
# Cut in half and saved: 0086_real_impossible.png -> 0086_left_real.png, 0086_right_impossible.png
# Cut in half and saved: 0087_impossible_real.png -> 0087_left_impossible.png, 0087_right_real.png
# Cut in half and saved: 0088_real_impossible.png -> 0088_left_real.png, 0088_right_impossible.png
# Cut in half and saved: 0089_impossible_real.png -> 0089_left_impossible.png, 0089_right_real.png
# Cut in half and saved: 0090_real_impossible.png -> 0090_left_real.png, 0090_right_impossible.png
# Cut in half and saved: 0091_impossible_real.png -> 0091_left_impossible.png, 0091_right_real.png
# Cut in half and saved: 0092_real_impossible.png -> 0092_left_real.png, 0092_right_impossible.png
# Cut in half and saved: 0093_impossible_real.png -> 0093_left_impossible.png, 0093_right_real.png
# Cut in half and saved: 0094_real_impossible.png -> 0094_left_real.png, 0094_right_impossible.png
# Cut in half and saved: 0095_impossible_real.png -> 0095_left_impossible.png, 0095_right_real.png
# Cut in half and saved: 0096_real_impossible.png -> 0096_left_real.png, 0096_right_impossible.png
# Cut in half and saved: 0097_impossible_real.png -> 0097_left_impossible.png, 0097_right_real.png
# Cut in half and saved: 0098_real_impossible.png -> 0098_left_real.png, 0098_right_impossible.png
# Cut in half and saved: 0099_impossible_real.png -> 0099_left_impossible.png, 0099_right_real.png
# Cut in half and saved: 0100_real_impossible.png -> 0100_left_real.png, 0100_right_impossible.png
# Cut in half and saved: 0101_impossible_real.png -> 0101_left_impossible.png, 0101_right_real.png
# Cut in half and saved: 0102_real_impossible.png -> 0102_left_real.png, 0102_right_impossible.png
# Cut in half and saved: 0103_impossible_real.png -> 0103_left_impossible.png, 0103_right_real.png
# Cut in half and saved: 0104_real_impossible.png -> 0104_left_real.png, 0104_right_impossible.png
# Cut in half and saved: 0105_impossible_real.png -> 0105_left_impossible.png, 0105_right_real.png
# Cut in half and saved: 0106_real_impossible.png -> 0106_left_real.png, 0106_right_impossible.png
# Cut in half and saved: 0107_impossible_real.png -> 0107_left_impossible.png, 0107_right_real.png
# Cut in half and saved: 0108_real_impossible.png -> 0108_left_real.png, 0108_right_impossible.png
# Cut in half and saved: 0109_impossible_real.png -> 0109_left_impossible.png, 0109_right_real.png
# Cut in half and saved: 0110_real_impossible.png -> 0110_left_real.png, 0110_right_impossible.png
# Cut in half and saved: 0111_impossible_real.png -> 0111_left_impossible.png, 0111_right_real.png
# Cut in half and saved: 0112_real_impossible.png -> 0112_left_real.png, 0112_right_impossible.png
# Cut in half and saved: 0113_impossible_real.png -> 0113_left_impossible.png, 0113_right_real.png
# Cut in half and saved: 0114_real_impossible.png -> 0114_left_real.png, 0114_right_impossible.png
# Cut in half and saved: 0115_impossible_real.png -> 0115_left_impossible.png, 0115_right_real.png
# Cut in half and saved: 0116_real_impossible.png -> 0116_left_real.png, 0116_right_impossible.png
# Cut in half and saved: 0117_impossible_real.png -> 0117_left_impossible.png, 0117_right_real.png
# Cut in half and saved: 0118_real_impossible.png -> 0118_left_real.png, 0118_right_impossible.png
# Cut in half and saved: 0119_impossible_real.png -> 0119_left_impossible.png, 0119_right_real.png
# Cut in half and saved: 0120_real_impossible.png -> 0120_left_real.png, 0120_right_impossible.png
# Cut in half and saved: 0121_impossible_real.png -> 0121_left_impossible.png, 0121_right_real.png
# Cut in half and saved: 0122_real_impossible.png -> 0122_left_real.png, 0122_right_impossible.png
# Cut in half and saved: 0123_impossible_real.png -> 0123_left_impossible.png, 0123_right_real.png
# Cut in half and saved: 0124_real_impossible.png -> 0124_left_real.png, 0124_right_impossible.png
# Cut in half and saved: 0125_impossible_real.png -> 0125_left_impossible.png, 0125_right_real.png
# Cut in half and saved: 0126_real_impossible.png -> 0126_left_real.png, 0126_right_impossible.png
# Cut in half and saved: 0127_impossible_real.png -> 0127_left_impossible.png, 0127_right_real.png
# Cut in half and saved: 0128_real_impossible.png -> 0128_left_real.png, 0128_right_impossible.png
# Cut in half and saved: 0129_impossible_real.png -> 0129_left_impossible.png, 0129_right_real.png
# Cut in half and saved: 0130_real_impossible.png -> 0130_left_real.png, 0130_right_impossible.png
# Cut in half and saved: 0131_impossible_real.png -> 0131_left_impossible.png, 0131_right_real.png
# Cut in half and saved: 0132_real_impossible.png -> 0132_left_real.png, 0132_right_impossible.png
# Cut in half and saved: 0133_impossible_real.png -> 0133_left_impossible.png, 0133_right_real.png
# Cut in half and saved: 0134_real_impossible.png -> 0134_left_real.png, 0134_right_impossible.png
# Cut in half and saved: 0135_impossible_real.png -> 0135_left_impossible.png, 0135_right_real.png
# Cut in half and saved: 0136_real_impossible.png -> 0136_left_real.png, 0136_right_impossible.png
# Cut in half and saved: 0137_impossible_real.png -> 0137_left_impossible.png, 0137_right_real.png
# Cut in half and saved: 0138_real_impossible.png -> 0138_left_real.png, 0138_right_impossible.png
# Cut in half and saved: 0139_impossible_real.png -> 0139_left_impossible.png, 0139_right_real.png
# Cut in half and saved: 0140_real_impossible.png -> 0140_left_real.png, 0140_right_impossible.png
# Cut in half and saved: 0141_impossible_real.png -> 0141_left_impossible.png, 0141_right_real.png
# Cut in half and saved: 0142_real_impossible.png -> 0142_left_real.png, 0142_right_impossible.png
# Cut in half and saved: 0143_impossible_real.png -> 0143_left_impossible.png, 0143_right_real.png
# Cut in half and saved: 0144_real_impossible.png -> 0144_left_real.png, 0144_right_impossible.png
# Cut in half and saved: 0145_impossible_real.png -> 0145_left_impossible.png, 0145_right_real.png
# Cut in half and saved: 0146_real_impossible.png -> 0146_left_real.png, 0146_right_impossible.png
# Cut in half and saved: 0147_impossible_real.png -> 0147_left_impossible.png, 0147_right_real.png
# Cut in half and saved: 0148_real_impossible.png -> 0148_left_real.png, 0148_right_impossible.png
# Cut in half and saved: 0149_impossible_real.png -> 0149_left_impossible.png, 0149_right_real.png
# Cut in half and saved: 0150_real_impossible.png -> 0150_left_real.png, 0150_right_impossible.png
# Cut in half and saved: 0151_impossible_real.png -> 0151_left_impossible.png, 0151_right_real.png
# Cut in half and saved: 0152_real_impossible.png -> 0152_left_real.png, 0152_right_impossible.png
# Cut in half and saved: 0153_impossible_real.png -> 0153_left_impossible.png, 0153_right_real.png
# Cut in half and saved: 0154_real_impossible.png -> 0154_left_real.png, 0154_right_impossible.png
# Cut in half and saved: 0155_impossible_real.png -> 0155_left_impossible.png, 0155_right_real.png
# Cut in half and saved: 0156_real_impossible.png -> 0156_left_real.png, 0156_right_impossible.png
# Cut in half and saved: 0157_impossible_real.png -> 0157_left_impossible.png, 0157_right_real.png
# Cut in half and saved: 0158_real_impossible.png -> 0158_left_real.png, 0158_right_impossible.png
# Cut in half and saved: 0159_impossible_real.png -> 0159_left_impossible.png, 0159_right_real.png
# Cut in half and saved: 0160_real_impossible.png -> 0160_left_real.png, 0160_right_impossible.png
# Cut in half and saved: 0161_impossible_real.png -> 0161_left_impossible.png, 0161_right_real.png
# Cut in half and saved: 0162_real_impossible.png -> 0162_left_real.png, 0162_right_impossible.png
# Cut in half and saved: 0163_impossible_real.png -> 0163_left_impossible.png, 0163_right_real.png
# Cut in half and saved: 0164_real_impossible.png -> 0164_left_real.png, 0164_right_impossible.png
# Cut in half and saved: 0165_impossible_real.png -> 0165_left_impossible.png, 0165_right_real.png
# Cut in half and saved: 0166_real_impossible.png -> 0166_left_real.png, 0166_right_impossible.png
# Cut in half and saved: 0167_impossible_real.png -> 0167_left_impossible.png, 0167_right_real.png
# Cut in half and saved: 0168_real_impossible.png -> 0168_left_real.png, 0168_right_impossible.png
# Cut in half and saved: 0169_impossible_real.png -> 0169_left_impossible.png, 0169_right_real.png
# Cut in half and saved: 0170_real_impossible.png -> 0170_left_real.png, 0170_right_impossible.png
# Cut in half and saved: 0171_impossible_real.png -> 0171_left_impossible.png, 0171_right_real.png
# Cut in half and saved: 0172_real_impossible.png -> 0172_left_real.png, 0172_right_impossible.png
# Cut in half and saved: 0173_impossible_real.png -> 0173_left_impossible.png, 0173_right_real.png
# Cut in half and saved: 0174_real_impossible.png -> 0174_left_real.png, 0174_right_impossible.png
# Cut in half and saved: 0175_impossible_real.png -> 0175_left_impossible.png, 0175_right_real.png
# Cut in half and saved: 0176_real_impossible.png -> 0176_left_real.png, 0176_right_impossible.png
# Cut in half and saved: 0177_impossible_real.png -> 0177_left_impossible.png, 0177_right_real.png
# Cut in half and saved: 0178_real_impossible.png -> 0178_left_real.png, 0178_right_impossible.png
# Cut in half and saved: 0179_impossible_real.png -> 0179_left_impossible.png, 0179_right_real.png
# Cut in half and saved: 0180_real_impossible.png -> 0180_left_real.png, 0180_right_impossible.png
# Cut in half and saved: 0181_impossible_real.png -> 0181_left_impossible.png, 0181_right_real.png
# Cut in half and saved: 0182_real_impossible.png -> 0182_left_real.png, 0182_right_impossible.png
# Cut in half and saved: 0183_impossible_real.png -> 0183_left_impossible.png, 0183_right_real.png
# Cut in half and saved: 0184_real_impossible.png -> 0184_left_real.png, 0184_right_impossible.png
# Cut in half and saved: 0185_impossible_real.png -> 0185_left_impossible.png, 0185_right_real.png
# Cut in half and saved: 0186_real_impossible.png -> 0186_left_real.png, 0186_right_impossible.png
# Cut in half and saved: 0187_impossible_real.png -> 0187_left_impossible.png, 0187_right_real.png
# Cut in half and saved: 0188_real_impossible.png -> 0188_left_real.png, 0188_right_impossible.png
# Cut in half and saved: 0189_impossible_real.png -> 0189_left_impossible.png, 0189_right_real.png
# Cut in half and saved: 0190_real_impossible.png -> 0190_left_real.png, 0190_right_impossible.png
# Cut in half and saved: 0191_impossible_real.png -> 0191_left_impossible.png, 0191_right_real.png
# Cut in half and saved: 0192_real_impossible.png -> 0192_left_real.png, 0192_right_impossible.png
# Cut in half and saved: 0193_impossible_real.png -> 0193_left_impossible.png, 0193_right_real.png
# Cut in half and saved: 0194_real_impossible.png -> 0194_left_real.png, 0194_right_impossible.png
# Cut in half and saved: 0195_impossible_real.png -> 0195_left_impossible.png, 0195_right_real.png
# Cut in half and saved: 0196_real_impossible.png -> 0196_left_real.png, 0196_right_impossible.png
# Cut in half and saved: 0197_impossible_real.png -> 0197_left_impossible.png, 0197_right_real.png
# Cut in half and saved: 0198_real_impossible.png -> 0198_left_real.png, 0198_right_impossible.png
# Cut in half and saved: 0199_impossible_real.png -> 0199_left_impossible.png, 0199_right_real.png
# Cut in half and saved: 0200_real_impossible.png -> 0200_left_real.png, 0200_right_impossible.png
# Cut in half and saved: 0954_real_impossible.png -> 0954_left_real.png, 0954_right_impossible.png
# Cut in half and saved: 0955_impossible_real.png -> 0955_left_impossible.png, 0955_right_real.png
# Cut in half and saved: 0956_real_impossible.png -> 0956_left_real.png, 0956_right_impossible.png
# Cut in half and saved: 0957_impossible_real.png -> 0957_left_impossible.png, 0957_right_real.png
# Cut in half and saved: 0958_real_impossible.png -> 0958_left_real.png, 0958_right_impossible.png
# Cut in half and saved: 0959_impossible_real.png -> 0959_left_impossible.png, 0959_right_real.png
# Cut in half and saved: 0960_real_impossible.png -> 0960_left_real.png, 0960_right_impossible.png
# Cut in half and saved: 0961_impossible_real.png -> 0961_left_impossible.png, 0961_right_real.png
# Cut in half and saved: 0962_real_impossible.png -> 0962_left_real.png, 0962_right_impossible.png
# Cut in half and saved: 0963_impossible_real.png -> 0963_left_impossible.png, 0963_right_real.png
# Cut in half and saved: 0964_real_impossible.png -> 0964_left_real.png, 0964_right_impossible.png
# Cut in half and saved: 0965_impossible_real.png -> 0965_left_impossible.png, 0965_right_real.png
# Cut in half and saved: 0966_real_impossible.png -> 0966_left_real.png, 0966_right_impossible.png
# Cut in half and saved: 0967_impossible_real.png -> 0967_left_impossible.png, 0967_right_real.png

# %% [markdown]
# As my dataset is ready, I named it RealImpossibleDataset, it will read data and returns to the labels and its images, which are inputs and ground truths (the label).

# %%
class RealImpossibleDataset(Dataset):
    def __init__(self, data_dir, file_list=None, transforms=None):
        self.data_dir = data_dir
        self.file_list = file_list or os.listdir(data_dir)
        self.transforms = transforms

    def __getitem__(self, idx):
        file_name = self.file_list[idx]
        img_path = os.path.join(self.data_dir, file_name)
        image = Image.open(img_path).convert("RGB")
        
        if "real" in file_name and "impossible" not in file_name:
            label = 1  # Real
        elif "impossible" in file_name:
            label = 0  # Impossible
        else:
            raise ValueError(f"Invalid filename format: {file_name}")

        if self.transforms:
            image = self.transforms(image)
        
        return {"image": image, "label": torch.tensor(label, dtype=torch.long)}

    def __len__(self):
        return len(self.file_list)

# %% [markdown]
# Transform in terms of size and color channels will be defining as following for more stable optimization

# %%
def get_transforms(target_size, for_network=True):
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    transform_funs = [
        transforms.Resize(target_size),
        transforms.CenterCrop(target_size)
    ]
    if for_network:
        transform_funs.extend([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])
    return transforms.Compose(transform_funs)

# %% [markdown]
# Here, I defined training and validation sets, which corresponds to 80% and 20%, respectively. After defining data loader, I visualize 15 images from the dataset.

# %%
def split_train_valid(data_dir, val_percent=0.2):
    file_names = os.listdir(data_dir)
    file_ids = list(range(len(file_names)))
    np.random.shuffle(file_ids)
    
    split = int(len(file_ids) * val_percent)
    valid_ids, train_ids = file_ids[:split], file_ids[split:]
    
    train_files = [file_names[i] for i in train_ids]
    valid_files = [file_names[i] for i in valid_ids]
    
    return train_files, valid_files

def build_dataloader(data_dir, file_list, batch_size, transforms):
    dataset = RealImpossibleDataset(data_dir, file_list, transforms)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    return dataloader

def visualize_samples(dataset, num_samples=15):
    """
    Visualize multiple samples from the dataset.
    """
    fig, axes = plt.subplots(3, 5, figsize=(15, 9)) 
    axes = axes.flatten()  # Flatten the axes for easy iteration

    for i, ax in enumerate(axes[:num_samples]):
        sample = dataset[i] 
        image = sample["image"].permute(1, 2, 0)  
        label = "Real" if sample["label"] == 1 else "Impossible"

        ax.imshow(image)
        ax.set_title(label)
        ax.axis("off")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Lastly, code runs in this part, which is named as main. Bstch size 128 is just for fun, i just adjusted it to be 10 batches. It gives an error that I did not remove while printing the images but it does print the images so I decided it is not a huge problem (but maybe it is a huge problem that I am not aware of).

# %%
def main():
    data_dir = FINALDATA_DIR

    transforms = get_transforms((100, 100))
    train_files, valid_files = split_train_valid(data_dir)

    batch_size = 128
    train_loader = build_dataloader(data_dir, train_files, batch_size, transforms)
    valid_loader = build_dataloader(data_dir, valid_files, batch_size, transforms)

    train_dataset = RealImpossibleDataset(data_dir, train_files, transforms)
    visualize_samples(train_dataset, num_samples=15)

    for batch in train_loader:
        images, labels = batch["image"], batch["label"]
        print(f"Batch size: {len(images)}")
        print(f"Labels: {labels}")
        break

    print(f"Train Loader Ready with {len(train_files)} samples")
    print(f"Validation Loader Ready with {len(valid_files)} samples")

if __name__ == "__main__":
    main()
